# %% [markdown]
# <a href="https://www.kaggle.com/giuliakaranxha/data-viz-exercise?scriptVersionId=84580336" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
my_data_filepath = "../input/covid19-healthy-diet-dataset/Food_Supply_Quantity_kg_Data.csv"

my_data= pd.read_csv(my_data_filepath, index_col='Country')
my_data.head()
# Out:
#                      Alcoholic Beverages  Animal fats  Animal Products  \
# Country
# Afghanistan                       0.0014       0.1973           9.4341
# Albania                           1.6719       0.1357          18.7684
# Algeria                           0.2711       0.0282           9.6334
# Angola                            5.8087       0.0560           4.9278
# Antigua and Barbuda               3.5764       0.0087          16.6613
#
#                      Aquatic Products, Other  Cereals - Excluding Beer  \
# Country
# Afghanistan                              0.0                   24.8097
# Albania                                  0.0                    5.7817
# Algeria                                  0.0                   13.6816
# Angola                                   0.0                    9.1085
# Antigua and Barbuda                      0.0                    5.9960
#
#                        Eggs  Fish, Seafood  Fruits - Excluding Wine    Meat  \
# Country
# ...

# %%
my_data.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
#        ...
#        'United Republic of Tanzania', 'United States of America', 'Uruguay',
#        'Uzbekistan', 'Vanuatu', 'Venezuela (Bolivarian Republic of)',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country', length=170)

# %%
my_data.columns
# Out:
# Index(['Alcoholic Beverages', 'Animal fats', 'Animal Products',
#        'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs',
#        'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat',
#        'Milk - Excluding Butter', 'Miscellaneous', 'Offals', 'Oilcrops',
#        'Pulses', 'Spices', 'Starchy Roots', 'Stimulants', 'Sugar & Sweeteners',
#        'Sugar Crops', 'Treenuts', 'Vegetable Oils', 'Vegetables',
#        'Vegetal Products', 'Obesity', 'Undernourished', 'Confirmed', 'Deaths',
#        'Recovered', 'Active', 'Population', 'Unit (all except Population)'],
#       dtype='object')

# %%
#Creating a Pivot Table with Country as index and the kg of Alcoholic Bev
heatmap1_data = pd.pivot_table(my_data, 
                     index=['Country'], 
                     values='Alcoholic Beverages')
heatmap1_data
#Bar Chart #1 using the Pivot table
plt.figure(figsize=(25,30))
sns.barplot(x= heatmap1_data['Alcoholic Beverages'] ,y= heatmap1_data.index)
# Out:
# <AxesSubplot:xlabel='Alcoholic Beverages', ylabel='Country'>

# %%
#Bar chart #2 without the Pivot Table

plt.figure(figsize=(20,30))

plt.title("Alcoholic Beverages per Country in kg")

sns.barplot(y=my_data.index ,x=my_data['Alcoholic Beverages'])
# Out:
# <AxesSubplot:title={'center':'Alcoholic Beverages per Country in kg'}, xlabel='Alcoholic Beverages', ylabel='Country'>

# %%
#Create a pivot table with Alcoholic bev & Obesity% 
heatmap2_data = pd.pivot_table(my_data, columns=('Country'),
                     values=['Alcoholic Beverages', 'Obesity'],
                     )
heatmap2_data
# Out:
# Country              Afghanistan  Albania  Algeria  Angola  \
# Alcoholic Beverages       0.0014   1.6719   0.2711  5.8087
# Obesity                   4.5000  22.3000  26.6000  6.8000
#
# Country              Antigua and Barbuda  Argentina  Armenia  Australia  \
# Alcoholic Beverages               3.5764     4.2672   0.4014     5.5436
# Obesity                          19.1000    28.5000  20.9000    30.4000
#
# Country              Austria  Azerbaijan  ...  United Republic of Tanzania  \
# Alcoholic Beverages   7.0215      3.5969  ...                       4.5185
# Obesity              21.9000     19.9000  ...                       7.1000
#
# Country              United States of America  Uruguay  Uzbekistan  Vanuatu  \
# Alcoholic Beverages                    4.8647   3.5664      0.6835   0.2424
# Obesity                               37.3000  28.9000     15.3000  23.5000
#
# Country              Venezuela (Bolivarian Republic of)  Vietnam    Yemen  \
# ...

# %%
#Creating a Scatter Plot 
plt.figure(figsize=(10,7))

sns.scatterplot(x=my_data['Obesity'], y=my_data['Animal fats'],  hue=my_data['Animal fats'])
plt.ylabel("Percentage of food intake (kg) animal fats ")
plt.xlabel("Obesity % each country")
plt.title("Animal fats consumption and Obesity %")
# Out:
# Text(0.5, 1.0, 'Animal fats consumption and Obesity %')

# %%
#With Regression Line
plt.figure(figsize=(10,7))

sns.regplot(x=my_data['Obesity'], y=my_data['Animal fats'])
plt.ylabel("Percentage of food intake (kg) animal fats ")
plt.xlabel("Obesity % each Country")
plt.title("Animal Fats Consumption and Obesity %")
# Out:
# Text(0.5, 1.0, 'Animal Fats Consumption and Obesity %')

# %%
sns.regplot(x=my_data['Obesity'], y=my_data['Alcoholic Beverages'])
plt.ylabel("Alcoholic Beverages consuption in kg ")
plt.xlabel("Obesity % each country")
plt.title("Alcoholic Beverages consumption and Obesity %")
# Out:
# Text(0.5, 1.0, 'Alcoholic Beverages consumption and Obesity %')

# %%
plt.figure(figsize=(10,6))

sns.regplot(x=my_data['Obesity'], y=my_data['Vegetables'])
plt.ylabel(" Vegetables consuption in kg ")
plt.xlabel("Obesity % each country")
plt.title("Veggies consumption and Obesity %")
plt.savefig('output.png', dpi=300)

# %%
plt.figure(figsize=(10,6))

sns.regplot(x=my_data['Obesity'], y=my_data['Eggs'])
plt.ylabel(" Percentage of food intake (kg) eggs ")
plt.xlabel("Obesity % each country")
plt.title("Eggs consumption and Obesity %")
# Out:
# Text(0.5, 1.0, 'Eggs consumption and Obesity %')
